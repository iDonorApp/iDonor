# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.12.0

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error', metrics=['accuracy'])

# %%
# Declare model inputs and outputs for training
xs = np.array([1, 2, 3, 4], dtype=float)
ys = np.array([1, 2, 3, 4], dtype=float)

# %%
# Train the model
history = model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 7.4894e-04 - accuracy: 0.2500
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 5.2014e-04 - accuracy: 0.2500
# Epoch 3/500
# 1/1 [==============================] - 0s 20ms/step - loss: 3.6138e-04 - accuracy: 0.2500
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5121e-04 - accuracy: 0.2500
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7477e-04 - accuracy: 0.2500
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2172e-04 - accuracy: 0.2500
# Epoch 7/500
# 1/1 [==============================] - 0s 15ms/step - loss: 8.4915e-05 - accuracy: 0.2500
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.9371e-05 - accuracy: 0.2500
# Epoch 9/500
# 1/1 [==============================] - 0s 13ms/step - loss: 4.1641e-05 - accuracy: 0.2500
# Epoch 10/500
# ...

# %%
loss = history.history['loss']
epochs = range(0,500)
plt.plot(epochs, loss, 'g', label='loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy = history.history['accuracy']
epochs = range(0,500)
plt.plot(epochs, accuracy, 'b', label='accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Make a prediction
hasil = np.squeeze(model.predict([2]))
decimal = float(hasil)
predict = print(round(decimal))
# Out:
# 1/1 [==============================] - 0s 173ms/step
# 2

# %%
# Saves model to .h5 format
# model.save(root_path + '/model/model.h5')

# %%
# Export the SavedModel
# export_dir = 'C:/Users/Daniel Deary/Downloads/tf'
# tf.saved_model.save(model, export_dir)

# %%
# Convert the Model
# converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
# tflite_model = converter.convert()

# %%
# Save the Model
# tflite_model_file = pathlib.Path('D:/kali')
# tflite_model_file.write_bytes(tflite_model)
